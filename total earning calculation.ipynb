# %%
# Total earning calculation
total_earning = 9000
bonus= 0.05
final_earning = 0
if total_earning>= 8000:
  bonus = total_earning * bonus
  final_earning = total_earning + bonus
  print("Your bonus is=",bonus)
  print("Your final amount is",final_earning)
else:
  print("No bonus for you")
  print("Your final earnings are",total_earning)
